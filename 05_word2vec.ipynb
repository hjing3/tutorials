# %% [markdown]
# ### Forked from Tensorflow word2vec tutorial

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.python.client import device_lib
def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/gpu:0']

# %% [markdown]
# ### Load data

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %% [markdown]
# ### Build dictionary and training data

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3082, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# ### Generate a training batch for the skip-gram model.

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3082 originated -> 5234 anarchism
# 3082 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3082 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %% [markdown]
# ### Build and train a skip-gram model.

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 32
embedding_size = 32  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 32    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/gpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.8) #0.333

with tf.Session(graph=graph, config=tf.ConfigProto(log_device_placement=True)) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  158.944732666
# Nearest to in: lamellar, tadeusz, fruity, deadly, capricious, review, encouraging, vapor,
# Nearest to have: riffs, skydiving, fable, southward, dowling, trained, mysticism, spaceflights,
# Nearest to their: stalls, landlocked, bipartite, inerrancy, ashanti, stressed, humans, reservation,
# Nearest to time: graziani, burlington, cannibals, prominence, longman, ewing, eugenic, disguised,
# Nearest to is: unfamiliar, christadelphians, unobservable, miraculously, anakin, fiesole, impermanent, tijuana,
# Nearest to system: excludes, preseason, orthonormal, gnu, contagion, vashem, stack, something,
# Nearest to for: honor, leaded, mains, medical, vara, franchise, hypopituitarism, leben,
# Nearest to seven: leith, glick, phases, vladivostok, hangul, amtrak, remained, manufacturers,
# Nearest to may: seated, annan, cora, indoors, spacious, exposures, evangelion, beira,
# Nearest to see: sternberg, hodge, mal, olympian, laid, tortured, disability, barclay,
# Nearest to than: hangout, fail, q, accessory, injera, harsher, dmc, reservation,
# Nearest to three: nugent, vertebrate, clairvoyance, sonja, integrator, pronounces, potencies, polytechnique,
# Nearest to up: misquoted, bathsheba, lui, again, cyprian, counterexamples, exposing, prospects,
# Nearest to however: hazmi, la, judicious, raises, battista, ingenious, nazionale, impure,
# Nearest to if: gated, retorted, entourage, fitna, clipper, hydrology, nome, calvinists,
# Nearest to more: abruptly, roof, unilateral, armas, airways, clemens, immature, seamstress,
# Average loss at step  2000 :  79.4645574431
# Average loss at step  4000 :  46.9768649516
# Average loss at step  6000 :  34.4396434467
# Average loss at step  8000 :  27.1810898758
# Average loss at step  10000 :  22.5294206969
# Nearest to in: from, on, ppg, worshipped, recipient, at, for, pro,
# Nearest to have: checking, has, delayed, withdrew, joint, forum, widely, bust,
# Nearest to their: stressed, some, acupuncture, written, this, bridge, capital, subclass,
# Nearest to time: benevolence, continually, animated, forms, manufacture, lower, assistant, diagnostic,
# Nearest to is: was, normally, are, franciscan, spike, leaving, underscore, cinema,
# Nearest to system: increased, accepted, converted, micha, believe, something, begins, supported,
# Nearest to for: on, from, with, in, or, aunt, withdrew, need,
# Nearest to seven: six, eight, four, three, five, two, c, navarre,
# Nearest to may: irv, knocking, hugh, mumford, structural, embraced, algae, photographer,
# Nearest to see: ayers, evolved, qualified, laos, homer, invested, healer, connected,
# Nearest to than: doesn, fail, messages, faces, busiest, changes, lists, educated,
# Nearest to three: six, four, five, posts, beckwith, two, one, seven,
# Nearest to up: columbian, establishment, problem, ignite, again, months, decide, takers,
# Nearest to however: james, initially, changed, read, attached, infrared, signs, suspending,
# Nearest to if: fine, gas, nome, violations, luis, inhabited, alps, schwartz,
# Nearest to more: requests, connected, claims, surrounded, claim, outer, perennial, balance,
# Average loss at step  12000 :  18.3950682256
# Average loss at step  14000 :  16.0514822173
# Average loss at step  16000 :  14.5241212463
# Average loss at step  18000 :  12.3694814619
# Average loss at step  20000 :  10.7870897851
# Nearest to in: worshipped, of, and, from, with, international, skeletal, national,
# Nearest to have: has, checking, had, be, laugh, karsh, broadcasts, planted,
# Nearest to their: his, some, its, clinical, this, many, campaign, intent,
# Nearest to time: benevolence, diverged, animated, multicellular, grabbing, nomadic, entire, manufacture,
# Nearest to is: was, normally, are, lunda, ali, governments, were, attitude,
# Nearest to system: accepted, begins, technology, extremely, increased, supported, males, favors,
# Nearest to for: trojan, of, on, aq, stanzas, worshipped, through, and,
# Nearest to seven: nine, eight, five, four, six, three, automaton, kosovo,
# Nearest to may: can, might, embraced, structural, studied, algae, irv, belief,
# Nearest to see: ayers, mileva, circumpolar, qualified, evolved, clashed, mohammad, blair,
# Nearest to than: doesn, rapidly, busiest, educated, messages, breath, sympathetic, cooking,
# Nearest to three: five, six, four, nine, eight, two, zero, one,
# Nearest to up: ignite, problem, bet, limited, canadians, decide, horizon, pencil,
# Nearest to however: closing, gland, term, subclass, aq, tissue, establish, methane,
# Nearest to if: fine, recurrent, violations, inhabited, when, kongo, tones, chiefs,
# Nearest to more: outer, connected, claim, less, differences, claims, respects, hail,
# Average loss at step  22000 :  10.6470165706
# Average loss at step  24000 :  9.97072683096
# Average loss at step  26000 :  8.8693813026
# Average loss at step  28000 :  8.61757175207
# Average loss at step  30000 :  7.62621600795
# Nearest to in: by, during, on, over, from, fleece, worshipped, however,
# Nearest to have: has, had, checking, spaceship, broadcasts, rubbish, centaurs, planted,
# Nearest to their: his, its, some, snoop, the, an, this, appendages,
# Nearest to time: diverged, pharaoh, nomadic, inca, manufacture, octane, process, grabbing,
# Nearest to is: was, normally, are, were, has, had, but, hamadan,
# Nearest to system: creative, accepted, inca, beach, dddddd, salzburg, technology, stanzas,
# Nearest to for: or, against, with, however, aq, fleece, stanzas, trojan,
# Nearest to seven: four, six, five, eight, nine, two, three, zero,
# Nearest to may: can, might, will, nighttime, marshalling, could, irv, should,
# Nearest to see: ayers, quarks, greyhound, clashed, paperback, discharged, abc, kb,
# Nearest to than: messages, mig, rapidly, busiest, cooking, educated, doesn, lays,
# Nearest to three: five, four, two, zero, seven, six, one, eight,
# Nearest to up: decide, bet, continued, anton, racks, them, ignite, innocence,
# Nearest to however: marsden, gland, fleece, over, aq, nucleosynthesis, closing, tissue,
# Nearest to if: fine, when, kongo, recurrent, violations, concurrently, could, wyoming,
# Nearest to more: outer, less, connected, claims, hail, claim, respects, polygon,
# Average loss at step  32000 :  7.9521654619
# Average loss at step  34000 :  7.42914182073
# Average loss at step  36000 :  7.18008212668
# Average loss at step  38000 :  6.70774533081
# Average loss at step  40000 :  6.35537028927
# Nearest to in: from, during, fleece, worshipped, through, on, against, quadra,
# Nearest to have: had, has, spaceship, widely, checking, be, broadcasts, withdrew,
# Nearest to their: his, its, our, the, sounds, her, justly, them,
# Nearest to time: manufacture, amendment, octane, lyceum, continually, xserve, novelty, obvious,
# Nearest to is: was, are, normally, were, became, although, but, hamadan,
# Nearest to system: accepted, jews, technology, reverence, salzburg, cameroun, males, grandmother,
# Nearest to for: with, against, from, into, through, fleece, without, dakota,
# Nearest to seven: six, four, three, eight, nine, five, one, two,
# Nearest to may: can, will, should, might, could, would, marshalling, nighttime,
# Nearest to see: ayers, greyhound, quarks, interjection, synagogue, grouse, regretted, powerbook,
# Nearest to than: rapidly, lays, doesn, busiest, sympathetic, cooking, spelling, educated,
# Nearest to three: five, six, seven, four, two, eight, one, nine,
# Nearest to up: anton, ignite, bet, dominic, continued, them, canadians, titles,
# Nearest to however: but, although, when, restraints, where, nucleosynthesis, legal, so,
# Nearest to if: when, derisively, is, fine, where, rejoiced, assuming, kongo,
# Nearest to more: less, outer, respects, connected, claims, hail, claim, performance,
# Average loss at step  42000 :  6.42053666782
# Average loss at step  44000 :  6.27465507555
# Average loss at step  46000 :  5.83926168656
# Average loss at step  48000 :  5.82818452805
# Average loss at step  50000 :  5.65588869005
# Nearest to in: against, during, through, closing, over, at, from, marsden,
# Nearest to have: had, having, spaceship, has, broadcasts, checking, include, rook,
# Nearest to their: its, his, her, our, justly, the, merger, biologically,
# Nearest to time: period, manufacture, process, clermont, compiler, way, grt, animated,
# Nearest to is: was, are, normally, but, wandered, newsstand, into, remy,
# Nearest to system: side, beach, reverence, numerous, technology, humane, nor, polynesia,
# Nearest to for: against, through, without, stanzas, aq, with, from, arguing,
# Nearest to seven: six, five, eight, four, zero, nine, three, two,
# Nearest to may: can, could, would, will, might, should, must, cannot,
# Nearest to see: greyhound, ayers, quarks, geoff, paperback, interjection, agronomy, regretted,
# Nearest to than: rapidly, doesn, much, sihanouk, lays, slaves, busiest, naturalism,
# Nearest to three: five, six, eight, four, nine, zero, seven, two,
# Nearest to up: them, back, continued, bet, decades, virtually, manifold, anton,
# Nearest to however: but, when, that, admits, innovative, if, therefore, within,
# Nearest to if: when, where, but, however, kongo, took, although, though,
# Nearest to more: less, respects, immensely, outer, connected, performance, acceleration, most,
# Average loss at step  52000 :  5.74899075156
# Average loss at step  54000 :  5.52306316984
# Average loss at step  56000 :  5.50580356199
# Average loss at step  58000 :  5.37668578964
# Average loss at step  60000 :  5.16335923368
# Nearest to in: over, during, through, outside, from, against, into, while,
# Nearest to have: had, be, phone, landau, checking, has, rook, slavs,
# Nearest to their: his, its, the, her, biologically, our, raja, appendages,
# Nearest to time: manufacture, wattle, process, period, foundation, way, compiler, pharaoh,
# Nearest to is: was, are, became, historia, normally, were, but, ali,
# Nearest to system: beach, permanence, salzburg, side, numerous, reverence, beijing, nor,
# Nearest to for: against, through, from, without, while, of, during, stanzas,
# Nearest to seven: six, five, four, eight, nine, three, zero, two,
# Nearest to may: can, could, would, might, will, should, must, cannot,
# Nearest to see: greyhound, platelets, ayers, paperback, geoff, grouse, interjection, quarks,
# Nearest to than: rapidly, lays, messages, fostering, sihanouk, cooking, staircase, busiest,
# Nearest to three: four, five, six, two, eight, nine, seven, one,
# Nearest to up: them, back, bet, me, continued, him, motivational, manifold,
# Nearest to however: but, so, though, that, analogue, recurrent, if, restraints,
# Nearest to if: when, although, though, but, where, however, are, took,
# Nearest to more: less, respects, performance, connected, most, immensely, litigation, outer,
# Average loss at step  62000 :  5.37369585669
# Average loss at step  64000 :  4.89007577842
# Average loss at step  66000 :  5.0035402478
# Average loss at step  68000 :  4.79236480099
# Average loss at step  70000 :  4.83922569203
# Nearest to in: under, through, at, during, against, and, without, among,
# Nearest to have: be, had, repelled, phone, having, landau, rook, quattro,
# Nearest to their: his, her, its, the, our, biologically, raja, hyperfine,
# Nearest to time: period, manufacture, way, wattle, animated, fungi, process, foundation,
# Nearest to is: was, are, normally, wandered, but, were, sx, became,
# Nearest to system: permanence, beach, salzburg, technology, reverence, future, china, beijing,
# Nearest to for: through, against, within, without, strabo, though, among, lure,
# Nearest to seven: five, six, nine, four, three, zero, eight, one,
# Nearest to may: can, could, would, should, might, must, will, cannot,
# Nearest to see: platelets, greyhound, ayers, grouse, paperback, geoff, interjection, quarks,
# Nearest to than: lays, rapidly, fostering, staircase, busiest, sihanouk, messages, leaving,
# Nearest to three: six, two, nine, four, five, eight, seven, pigweed,
# Nearest to up: back, him, them, intended, canadians, bet, out, me,
# Nearest to however: while, but, though, which, that, so, bckgr, innovative,
# Nearest to if: where, though, when, although, but, however, fleece, hooks,
# Nearest to more: less, rather, connected, outer, either, respects, litigation, performance,
# Average loss at step  72000 :  4.82705696917
# Average loss at step  74000 :  4.98343854553
# Average loss at step  76000 :  4.86009335518
# Average loss at step  78000 :  4.93458851492
# Average loss at step  80000 :  4.72028173697
# Nearest to in: through, within, during, under, against, while, among, from,
# Nearest to have: having, be, had, landau, checking, has, rook, were,
# Nearest to their: its, his, her, our, the, them, biologically, any,
# Nearest to time: period, manufacture, wattle, chain, process, opposed, satire, grt,
# Nearest to is: was, normally, are, lunda, but, remy, though, became,
# Nearest to system: permanence, switched, term, tissue, fricative, beijing, poorly, action,
# Nearest to for: through, against, from, within, without, during, at, while,
# Nearest to seven: eight, four, six, three, nine, five, one, ingrained,
# Nearest to may: can, might, will, could, would, should, must, cannot,
# Nearest to see: greyhound, platelets, ayers, grouse, geoff, quarks, andersson, trie,
# Nearest to than: fostering, rapidly, messages, lays, cooking, kickoffs, sihanouk, busiest,
# Nearest to three: four, two, five, seven, six, pigweed, one, zero,
# Nearest to up: me, back, them, him, hydroxyproline, canadians, manifold, motivational,
# Nearest to however: while, when, but, before, and, though, that, during,
# Nearest to if: though, although, where, while, when, however, took, is,
# Nearest to more: less, most, respects, performance, rife, immensely, hail, hendrick,
# Average loss at step  82000 :  4.5075953005
# Average loss at step  84000 :  4.6693852756
# Average loss at step  86000 :  4.65241132212
# Average loss at step  88000 :  4.63157607016
# Average loss at step  90000 :  4.58103226542
# Nearest to in: at, through, under, on, and, against, within, near,
# Nearest to have: landau, twice, rook, having, ethanol, had, include, briton,
# Nearest to their: its, his, her, our, raja, biologically, hyperfine, amplification,
# Nearest to time: period, manufacture, chain, wattle, size, year, process, week,
# Nearest to is: was, became, normally, were, lunda, terraced, historia, ignatius,
# Nearest to system: permanence, animal, glider, poorly, numerous, design, fricative, infanticide,
# Nearest to for: through, against, without, from, lure, primate, and, arguing,
# Nearest to seven: eight, six, four, nine, five, three, hails, one,
# Nearest to may: might, could, can, will, should, must, would, cannot,
# Nearest to see: greyhound, platelets, ayers, geoff, andersson, sloped, exterminated, circumpolar,
# Nearest to than: rapidly, fostering, lays, vowels, star, sihanouk, or, mistaking,
# Nearest to three: four, two, six, pigweed, eight, five, entebbe, gul,
# Nearest to up: them, him, me, back, hydroxyproline, intended, manifold, bet,
# Nearest to however: when, but, while, bckgr, though, before, later, kx,
# Nearest to if: though, took, but, where, when, although, however, carrot,
# Nearest to more: less, respects, ahimelech, plagiarism, institutes, immensely, rife, most,
# Average loss at step  92000 :  4.78358358043
# Average loss at step  94000 :  4.63253913796
# Average loss at step  96000 :  4.55011860108
# Average loss at step  98000 :  4.76394518566
# Average loss at step  100000 :  4.60299230701
# Nearest to in: through, among, until, and, within, corte, during, representationalism,
# Nearest to have: landau, had, having, knuckle, has, spaceship, include, disappearances,
# Nearest to their: its, his, our, her, the, any, biologically, washtenaw,
# Nearest to time: period, manufacture, wattle, size, way, week, process, reason,
# Nearest to is: was, became, normally, assisted, were, violate, terraced, contains,
# Nearest to system: design, animal, beach, poorly, glider, permanence, future, computer,
# Nearest to for: through, against, without, among, under, liaisons, guardians, cholera,
# Nearest to seven: four, six, three, nine, eight, five, one, two,
# Nearest to may: could, would, should, might, will, can, must, cannot,
# Nearest to see: platelets, grouse, greyhound, ayers, geoff, duncan, circumpolar, exterminated,
# Nearest to than: rapidly, fostering, busiest, lays, sihanouk, vowels, dumont, kickoffs,
# Nearest to three: four, six, seven, five, eight, two, zero, nine,
# Nearest to up: him, back, them, me, intended, hydroxyproline, down, continued,
# Nearest to however: but, while, bckgr, thus, today, currently, that, though,
# Nearest to if: though, where, while, took, when, although, however, like,
# Nearest to more: less, respects, ahimelech, plagiarism, either, theropods, immensely, outer,

# %% [markdown]
# ### Visualize the embeddings

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)
  plt.show()

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
